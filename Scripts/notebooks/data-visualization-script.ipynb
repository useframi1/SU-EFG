# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("../Data/visualization_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4826 entries, 0 to 4825
# Data columns (total 41 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ClientID                              4826 non-null   int64
#  1   Gender                                4826 non-null   object
#  2   Age                                   4826 non-null   int64
#  3   RiskRate                              4826 non-null   object
#  4   CompletedOrdersRatio                  4826 non-null   float64
#  5   CanceledOrdersRatio                   4826 non-null   float64
#  6   AvgPrice                              4826 non-null   float64
#  7   OrderType_Buy                         4826 non-null   float64
#  8   OrderType_Sell                        4826 non-null   float64
#  9   ExecutionStatus_Executed              4826 non-null   float64
#  10  ExecutionStatus_NotExecuted           4826 non-null   float64
#  11  ExecutionStatus_PartiallyExecuted     4826 non-null   float64
#  12  SectorName_RealEstate                 4826 non-null   float64
#  13  SectorName_Financials                 4826 non-null   float64
#  14  SectorName_Materials                  4826 non-null   float64
#  15  SectorName_ConsumerDiscretionary      4826 non-null   float64
#  16  SectorName_Industries                 4826 non-null   float64
#  17  SectorName_HealthCare                 4826 non-null   float64
#  18  SectorName_InformationTechnology      4826 non-null   float64
#  19  SectorName_ConsumerStaples            4826 non-null   float64
#  20  SectorName_INDUSTRIAL                 4826 non-null   float64
#  21  SectorName_SERVICES                   4826 non-null   float64
#  22  SectorName_Energy                     4826 non-null   float64
#  23  SectorName_BasicMaterials             4826 non-null   float64
#  24  SectorName_INVESTMENT                 4826 non-null   float64
#  25  SectorName_TelecommunicationServices  4826 non-null   float64
#  26  SectorName_REALESTATE                 4826 non-null   float64
#  27  SectorName_Telecommunications         4826 non-null   float64
#  28  SectorName_FOOD                       4826 non-null   float64
#  29  SectorName_Others                     4826 non-null   float64
#  30  SectorName_Tourism                    4826 non-null   float64
#  31  SectorName_ConsumerServices           4826 non-null   float64
#  32  SectorName_Utilities                  4826 non-null   float64
#  33  SectorName_PharmaceuticalIndustries   4826 non-null   float64
#  34  IsDormant                             4826 non-null   int64
#  35  AvgOrderRate_Difference               4826 non-null   float64
#  36  AvgQuantityOrderedRate_Difference     4826 non-null   float64
#  37  AvgExecutedQuantityRatio              4826 non-null   float64
#  38  ClosedAccountsRatio                   4826 non-null   float64
#  39  SuspendedAccountsRatio                4826 non-null   float64
#  40  Churned                               4826 non-null   int64
# dtypes: float64(35), int64(4), object(2)
# memory usage: 1.5+ MB

# %%
# Specify the columns to plot
columns = [
    "Age",
    "CompletedOrdersRatio",
    "CanceledOrdersRatio",
    "AvgPrice",
    "AvgOrderRate_Difference",
    "AvgQuantityOrderedRate_Difference",
    "AvgExecutedQuantityRatio",
    "ClosedAccountsRatio",
]

# Create a pair plot with 'Churned' as hue
sns.pairplot(df, vars=columns)

# Show the plot
plt.show()

# %%
test_df = pd.read_csv("../Data/TestSet.csv")

# %%
test_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2737 entries, 0 to 2736
# Data columns (total 446 columns):
#  #    Column                                  Dtype
# ---   ------                                  -----
#  0    Age                                     float64
#  1    NumOfAccounts                           float64
#  2    NumOfClosedAccounts                     float64
#  3    NumOfCompletedOrders                    float64
#  4    NumOfCanceledOrders                     float64
#  5    TotalExecutedQuantity                   float64
#  6    TotalQuantity                           float64
#  7    AvgPrice                                float64
#  8    OrderType_Buy                           float64
#  9    OrderType_Sell                          float64
#  10   SecurityID_0                            float64
#  11   SecurityID_1                            float64
#  12   SecurityID_2                            float64
#  13   SecurityID_3                            float64
#  14   SecurityID_4                            float64
#  15   SecurityID_5                            float64
#  16   SecurityID_6                            float64
#  17   SecurityID_7                            float64
#  18   SecurityID_8                            float64
#  19   SecurityID_9                            float64
#  20   SecurityID_10                           float64
#  21   SecurityID_11                           float64
#  22   SecurityID_12                           float64
#  23   SecurityID_13                           float64
#  24   SecurityID_14                           float64
#  25   SecurityID_15                           float64
#  26   SecurityID_16                           float64
#  27   SecurityID_17                           float64
#  28   SecurityID_18                           float64
#  29   SecurityID_19                           float64
#  30   SecurityID_20                           float64
#  31   SecurityID_21                           float64
#  32   SecurityID_22                           float64
#  33   SecurityID_23                           float64
#  34   SecurityID_24                           float64
#  35   SecurityID_25                           float64
#  36   SecurityID_26                           float64
#  37   SecurityID_27                           float64
#  38   SecurityID_28                           float64
#  39   SecurityID_29                           float64
#  40   SecurityID_30                           float64
#  41   SecurityID_31                           float64
#  42   SecurityID_32                           float64
#  43   SecurityID_33                           float64
#  44   SecurityID_34                           float64
#  45   SecurityID_35                           float64
#  46   SecurityID_36                           float64
#  47   SecurityID_37                           float64
#  48   SecurityID_38                           float64
#  49   SecurityID_39                           float64
#  50   SecurityID_40                           float64
#  51   SecurityID_41                           float64
#  52   SecurityID_42                           float64
#  53   SecurityID_43                           float64
#  54   SecurityID_44                           float64
#  55   SecurityID_45                           float64
#  56   SecurityID_46                           float64
#  57   SecurityID_47                           float64
#  58   SecurityID_48                           float64
#  59   SecurityID_49                           float64
#  60   SecurityID_50                           float64
#  61   SecurityID_51                           float64
#  62   SecurityID_52                           float64
#  63   SecurityID_53                           float64
#  64   SecurityID_54                           float64
#  65   SecurityID_55                           float64
#  66   SecurityID_56                           float64
#  67   SecurityID_57                           float64
#  68   SecurityID_58                           float64
#  69   SecurityID_59                           float64
#  70   SecurityID_60                           float64
#  71   SecurityID_61                           float64
#  72   SecurityID_62                           float64
#  73   SecurityID_63                           float64
#  74   SecurityID_64                           float64
#  75   SecurityID_65                           float64
#  76   SecurityID_66                           float64
#  77   SecurityID_67                           float64
#  78   SecurityID_68                           float64
#  79   SecurityID_69                           float64
#  80   SecurityID_70                           float64
#  81   SecurityID_71                           float64
#  82   SecurityID_72                           float64
#  83   SecurityID_73                           float64
#  84   SecurityID_74                           float64
#  85   SecurityID_75                           float64
#  86   SecurityID_76                           float64
#  87   SecurityID_77                           float64
#  88   SecurityID_78                           float64
#  89   SecurityID_79                           float64
#  90   SecurityID_80                           float64
#  91   SecurityID_81                           float64
#  92   SecurityID_82                           float64
#  93   SecurityID_83                           float64
#  94   SecurityID_84                           float64
#  95   SecurityID_85                           float64
#  96   SecurityID_86                           float64
#  97   SecurityID_87                           float64
#  98   SecurityID_88                           float64
#  99   SecurityID_89                           float64
#  100  SecurityID_90                           float64
#  101  SecurityID_91                           float64
#  102  SecurityID_92                           float64
#  103  SecurityID_93                           float64
#  104  SecurityID_94                           float64
#  105  SecurityID_95                           float64
#  106  SecurityID_96                           float64
#  107  SecurityID_97                           float64
#  108  SecurityID_98                           float64
#  109  SecurityID_99                           float64
#  110  SecurityID_100                          float64
#  111  SecurityID_101                          float64
#  112  SecurityID_102                          float64
#  113  SecurityID_103                          float64
#  114  SecurityID_104                          float64
#  115  SecurityID_105                          float64
#  116  SecurityID_106                          float64
#  117  SecurityID_107                          float64
#  118  SecurityID_108                          float64
#  119  SecurityID_109                          float64
#  120  SecurityID_110                          float64
#  121  SecurityID_111                          float64
#  122  SecurityID_112                          float64
#  123  SecurityID_113                          float64
#  124  SecurityID_114                          float64
#  125  SecurityID_115                          float64
#  126  SecurityID_116                          float64
#  127  SecurityID_117                          float64
#  128  SecurityID_118                          float64
#  129  SecurityID_119                          float64
#  130  SecurityID_120                          float64
#  131  SecurityID_121                          float64
#  132  SecurityID_122                          float64
#  133  SecurityID_123                          float64
#  134  SecurityID_124                          float64
#  135  SecurityID_125                          float64
#  136  SecurityID_126                          float64
#  137  SecurityID_127                          float64
#  138  SecurityID_128                          float64
#  139  SecurityID_129                          float64
#  140  SecurityID_130                          float64
#  141  SecurityID_131                          float64
#  142  SecurityID_132                          float64
#  143  SecurityID_133                          float64
#  144  SecurityID_134                          float64
#  145  SecurityID_135                          float64
#  146  SecurityID_136                          float64
#  147  SecurityID_137                          float64
#  148  SecurityID_138                          float64
#  149  SecurityID_139                          float64
#  150  SecurityID_140                          float64
#  151  SecurityID_141                          float64
#  152  SecurityID_142                          float64
#  153  SecurityID_143                          float64
#  154  SecurityID_144                          float64
#  155  SecurityID_145                          float64
#  156  SecurityID_146                          float64
#  157  SecurityID_147                          float64
#  158  SecurityID_148                          float64
#  159  SecurityID_149                          float64
#  160  SecurityID_150                          float64
#  161  SecurityID_151                          float64
#  162  SecurityID_152                          float64
#  163  SecurityID_153                          float64
#  164  SecurityID_154                          float64
#  165  SecurityID_155                          float64
#  166  SecurityID_156                          float64
#  167  SecurityID_157                          float64
#  168  SecurityID_158                          float64
#  169  SecurityID_159                          float64
#  170  SecurityID_160                          float64
#  171  SecurityID_161                          float64
#  172  SecurityID_162                          float64
#  173  SecurityID_163                          float64
#  174  SecurityID_164                          float64
#  175  SecurityID_165                          float64
#  176  SecurityID_166                          float64
#  177  SecurityID_167                          float64
#  178  SecurityID_168                          float64
#  179  SecurityID_169                          float64
#  180  SecurityID_170                          float64
#  181  SecurityID_171                          float64
#  182  SecurityID_172                          float64
#  183  SecurityID_173                          float64
#  184  SecurityID_174                          float64
#  185  SecurityID_175                          float64
#  186  SecurityID_176                          float64
#  187  SecurityID_177                          float64
#  188  SecurityID_178                          float64
#  189  SecurityID_179                          float64
#  190  SecurityID_180                          float64
#  191  SecurityID_181                          float64
#  192  SecurityID_182                          float64
#  193  SecurityID_183                          float64
#  194  SecurityID_184                          float64
#  195  SecurityID_185                          float64
#  196  SecurityID_186                          float64
#  197  SecurityID_187                          float64
#  198  SecurityID_188                          float64
#  199  SecurityID_189                          float64
#  200  SecurityID_190                          float64
#  201  SecurityID_191                          float64
#  202  SecurityID_192                          float64
#  203  SecurityID_193                          float64
#  204  SecurityID_194                          float64
#  205  SecurityID_195                          float64
#  206  SecurityID_196                          float64
#  207  SecurityID_197                          float64
#  208  SecurityID_198                          float64
#  209  SecurityID_199                          float64
#  210  SecurityID_200                          float64
#  211  SecurityID_201                          float64
#  212  SecurityID_202                          float64
#  213  SecurityID_203                          float64
#  214  SecurityID_204                          float64
#  215  SecurityID_205                          float64
#  216  SecurityID_206                          float64
#  217  SecurityID_207                          float64
#  218  SecurityID_208                          float64
#  219  SecurityID_209                          float64
#  220  SecurityID_210                          float64
#  221  SecurityID_211                          float64
#  222  SecurityID_212                          float64
#  223  SecurityID_213                          float64
#  224  SecurityID_214                          float64
#  225  SecurityID_215                          float64
#  226  SecurityID_216                          float64
#  227  SecurityID_217                          float64
#  228  SecurityID_218                          float64
#  229  SecurityID_219                          float64
#  230  SecurityID_220                          float64
#  231  SecurityID_221                          float64
#  232  SecurityID_222                          float64
#  233  SecurityID_223                          float64
#  234  SecurityID_224                          float64
#  235  SecurityID_225                          float64
#  236  SecurityID_226                          float64
#  237  SecurityID_227                          float64
#  238  SecurityID_228                          float64
#  239  SecurityID_229                          float64
#  240  SecurityID_230                          float64
#  241  SecurityID_231                          float64
#  242  SecurityID_232                          float64
#  243  SecurityID_233                          float64
#  244  SecurityID_234                          float64
#  245  SecurityID_235                          float64
#  246  SecurityID_236                          float64
#  247  SecurityID_237                          float64
#  248  SecurityID_238                          float64
#  249  SecurityID_239                          float64
#  250  SecurityID_240                          float64
#  251  SecurityID_241                          float64
#  252  SecurityID_242                          float64
#  253  SecurityID_243                          float64
#  254  SecurityID_244                          float64
#  255  SecurityID_245                          float64
#  256  SecurityID_246                          float64
#  257  SecurityID_247                          float64
#  258  SecurityID_248                          float64
#  259  SecurityID_249                          float64
#  260  SecurityID_250                          float64
#  261  SecurityID_251                          float64
#  262  SecurityID_252                          float64
#  263  SecurityID_253                          float64
#  264  SecurityID_254                          float64
#  265  SecurityID_255                          float64
#  266  SecurityID_256                          float64
#  267  SecurityID_257                          float64
#  268  SecurityID_258                          float64
#  269  SecurityID_259                          float64
#  270  SecurityID_260                          float64
#  271  SecurityID_261                          float64
#  272  SecurityID_262                          float64
#  273  SecurityID_263                          float64
#  274  SecurityID_264                          float64
#  275  SecurityID_265                          float64
#  276  SecurityID_266                          float64
#  277  SecurityID_267                          float64
#  278  SecurityID_269                          float64
#  279  SecurityID_270                          float64
#  280  SecurityID_271                          float64
#  281  SecurityID_272                          float64
#  282  SecurityID_273                          float64
#  283  SecurityID_274                          float64
#  284  SecurityID_275                          float64
#  285  SecurityID_276                          float64
#  286  SecurityID_277                          float64
#  287  SecurityID_278                          float64
#  288  SecurityID_279                          float64
#  289  SecurityID_280                          float64
#  290  SecurityID_281                          float64
#  291  SecurityID_282                          float64
#  292  SecurityID_283                          float64
#  293  SecurityID_284                          float64
#  294  SecurityID_285                          float64
#  295  SecurityID_286                          float64
#  296  SecurityID_287                          float64
#  297  SecurityID_288                          float64
#  298  SecurityID_291                          float64
#  299  SecurityID_292                          float64
#  300  SecurityID_293                          float64
#  301  SecurityID_294                          float64
#  302  SecurityID_295                          float64
#  303  SecurityID_296                          float64
#  304  SecurityID_297                          float64
#  305  SecurityID_298                          float64
#  306  SecurityID_299                          float64
#  307  SecurityID_300                          float64
#  308  SecurityID_301                          float64
#  309  SecurityID_302                          float64
#  310  SecurityID_303                          float64
#  311  SecurityID_304                          float64
#  312  SecurityID_305                          float64
#  313  SecurityID_306                          float64
#  314  SecurityID_307                          float64
#  315  SecurityID_308                          float64
#  316  SecurityID_309                          float64
#  317  SecurityID_310                          float64
#  318  SecurityID_311                          float64
#  319  SecurityID_312                          float64
#  320  SecurityID_313                          float64
#  321  SecurityID_314                          float64
#  322  SecurityID_315                          float64
#  323  SecurityID_316                          float64
#  324  SecurityID_317                          float64
#  325  SecurityID_318                          float64
#  326  SecurityID_319                          float64
#  327  SecurityID_320                          float64
#  328  SecurityID_321                          float64
#  329  SecurityID_322                          float64
#  330  SecurityID_323                          float64
#  331  SecurityID_324                          float64
#  332  SecurityID_325                          float64
#  333  SecurityID_326                          float64
#  334  SecurityID_327                          float64
#  335  SecurityID_328                          float64
#  336  SecurityID_329                          float64
#  337  SecurityID_330                          float64
#  338  SecurityID_331                          float64
#  339  SecurityID_332                          float64
#  340  SecurityID_333                          float64
#  341  SecurityID_334                          float64
#  342  SecurityID_335                          float64
#  343  SecurityID_336                          float64
#  344  SecurityID_337                          float64
#  345  OrderVia_Online                         float64
#  346  OrderVia_CallCenter                     float64
#  347  OrderVia_Telephone                      float64
#  348  OrderVia_Email                          float64
#  349  ExecutionStatus_Executed                float64
#  350  ExecutionStatus_NotExecuted             float64
#  351  ExecutionStatus_PartiallyExecuted       float64
#  352  SectorName_RealEstate                   float64
#  353  SectorName_Financials                   float64
#  354  SectorName_Materials                    float64
#  355  SectorName_ConsumerDiscretionary        float64
#  356  SectorName_Industries                   float64
#  357  SectorName_HealthCare                   float64
#  358  SectorName_InformationTechnology        float64
#  359  SectorName_ConsumerStaples              float64
#  360  SectorName_INDUSTRIAL                   float64
#  361  SectorName_SERVICES                     float64
#  362  SectorName_Energy                       float64
#  363  SectorName_BasicMaterials               float64
#  364  SectorName_INVESTMENT                   float64
#  365  SectorName_TelecommunicationServices    float64
#  366  SectorName_REALESTATE                   float64
#  367  SectorName_Telecommunications           float64
#  368  SectorName_FOOD                         float64
#  369  SectorName_Others                       float64
#  370  SectorName_Tourism                      float64
#  371  SectorName_ConsumerServices             float64
#  372  SectorName_Utilities                    float64
#  373  SectorName_Trade                        float64
#  374  SectorName_PharmaceuticalIndustries     float64
#  375  AvgOrderRate_Start                      float64
#  376  AvgOrderRate_End                        float64
#  377  AvgQuantityOrderedRate_Start            float64
#  378  AvgQuantityOrderedRate_End              float64
#  379  AvgQuantityOrderedRate_Difference       float64
#  380  AvgQuantityPerAccount_Start             float64
#  381  AvgQuantityPerAccount_End               float64
#  382  AvgQuantityPerAccount_Difference        float64
#  383  Gender_Female                           int64
#  384  Gender_Male                             int64
#  385  RiskRate_Low                            int64
#  386  RiskRate_Medium                         int64
#  387  RiskRate_NotAssigned                    int64
#  388  ClientTypeName_Companies                int64
#  389  ClientTypeName_Individuals              int64
#  390  FirstOpenAccountDate_Year_1998          int64
#  391  FirstOpenAccountDate_Year_2000          int64
#  392  FirstOpenAccountDate_Year_2001          int64
#  393  FirstOpenAccountDate_Year_2004          int64
#  394  FirstOpenAccountDate_Year_2005          int64
#  395  FirstOpenAccountDate_Year_2006          int64
#  396  FirstOpenAccountDate_Year_2007          int64
#  397  FirstOpenAccountDate_Year_2008          int64
#  398  FirstOpenAccountDate_Year_2009          int64
#  399  FirstOpenAccountDate_Year_2010          int64
#  400  FirstOpenAccountDate_Year_2011          int64
#  401  FirstOpenAccountDate_Year_2012          int64
#  402  FirstOpenAccountDate_Year_2013          int64
#  403  FirstOpenAccountDate_Year_2014          int64
#  404  FirstOpenAccountDate_Year_2015          int64
#  405  FirstOpenAccountDate_Year_2016          int64
#  406  FirstOpenAccountDate_Year_2017          int64
#  407  FirstOpenAccountDate_Year_2018          int64
#  408  FirstOpenAccountDate_Year_2019          int64
#  409  FirstOpenAccountDate_Year_2020          int64
#  410  FirstOpenAccountDate_Year_2021          int64
#  411  FirstOpenAccountDate_Year_2022          int64
#  412  FirstOpenAccountDate_Year_2023          int64
#  413  FirstOpenAccountDate_Year_2024          int64
#  414  LastOpenAccountDate_Year_1998           int64
#  415  LastOpenAccountDate_Year_2000           int64
#  416  LastOpenAccountDate_Year_2001           int64
#  417  LastOpenAccountDate_Year_2005           int64
#  418  LastOpenAccountDate_Year_2006           int64
#  419  LastOpenAccountDate_Year_2007           int64
#  420  LastOpenAccountDate_Year_2008           int64
#  421  LastOpenAccountDate_Year_2009           int64
#  422  LastOpenAccountDate_Year_2010           int64
#  423  LastOpenAccountDate_Year_2011           int64
#  424  LastOpenAccountDate_Year_2012           int64
#  425  LastOpenAccountDate_Year_2013           int64
#  426  LastOpenAccountDate_Year_2014           int64
#  427  LastOpenAccountDate_Year_2015           int64
#  428  LastOpenAccountDate_Year_2016           int64
#  429  LastOpenAccountDate_Year_2017           int64
#  430  LastOpenAccountDate_Year_2018           int64
#  431  LastOpenAccountDate_Year_2019           int64
#  432  LastOpenAccountDate_Year_2020           int64
#  433  LastOpenAccountDate_Year_2021           int64
#  434  LastOpenAccountDate_Year_2022           int64
#  435  LastOpenAccountDate_Year_2023           int64
#  436  LastOpenAccountDate_Year_2024           int64
#  437  FirstOrderDateAcrossAccounts_Year_0     int64
#  438  FirstOrderDateAcrossAccounts_Year_2022  int64
#  439  FirstOrderDateAcrossAccounts_Year_2023  int64
#  440  FirstOrderDateAcrossAccounts_Year_2024  int64
#  441  LastOrderDateAcrossAccounts_Year_0      int64
#  442  LastOrderDateAcrossAccounts_Year_2022   int64
#  443  LastOrderDateAcrossAccounts_Year_2023   int64
#  444  LastOrderDateAcrossAccounts_Year_2024   int64
#  445  Churned                                 int64
# dtypes: float64(383), int64(63)
# memory usage: 9.3 MB

# %%
X_test = test_df.iloc[:, :-1].to_numpy()
y_test = test_df.iloc[:, -1].to_numpy()

# %%
with open("../RandomForestModel.pkl", "rb") as f:
    model = pickle.load(f)

# %%
predictions = model.predict(X_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      1387
#            1       0.93      0.90      0.92      1350
#
#     accuracy                           0.92      2737
#    macro avg       0.92      0.92      0.92      2737
# weighted avg       0.92      0.92      0.92      2737

# %%
cm = confusion_matrix(y_test, predictions)

# Create a heatmap
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=0.5, square=True, cmap="Blues")
plt.ylabel("Actual Churn")
plt.xlabel("Predicted Churn")
plt.title("Confusion Matrix", size=15)
plt.show()

# %%
importances = model.feature_importances_
feature_importances = pd.Series(
    importances, index=test_df.columns[:-1]
)  # excluding the target variable
top_n = 30
top_n_importances = feature_importances.sort_values(ascending=False)[:top_n]

# Now plot the top N importances
plt.figure(figsize=(10, 10))
top_n_importances.plot(kind="barh")
plt.title("Top {} Feature Importances".format(top_n))
plt.show()

# %%
churn_rate = test_df["Churned"].mean() * 100
print(f"Churn Rate: {churn_rate:.2f}%")
# Out:
# Churn Rate: 49.32%

# %%
correlations = (
    test_df.loc[:, (test_df != test_df.iloc[0]).any()].corr()["Churned"].sort_values()
)
print("Most Positive Correlations:\n", correlations.tail(10))
print("\nMost Negative Correlations:\n", correlations.head(10))
# Out:
# Most Positive Correlations:
#  FirstOpenAccountDate_Year_2001            0.038136
# SecurityID_170                            0.038374
# SecurityID_284                            0.043238
# SecurityID_228                            0.047516
# OrderVia_Email                            0.049172
# NumOfClosedAccounts                       0.230485
# NumOfAccounts                             0.235886
# FirstOrderDateAcrossAccounts_Year_2022    0.452383
# LastOrderDateAcrossAccounts_Year_2022     0.458824
# Churned                                   1.000000
# Name: Churned, dtype: float64
#
# Most Negative Correlations:
#  LastOrderDateAcrossAccounts_Year_2024    -0.571657
# FirstOrderDateAcrossAccounts_Year_2024   -0.561689
# AvgQuantityOrderedRate_End               -0.333257
# NumOfCompletedOrders                     -0.323433
# RiskRate_NotAssigned                     -0.322177
# NumOfCanceledOrders                      -0.319687
# LastOpenAccountDate_Year_2023            -0.311625
# FirstOpenAccountDate_Year_2023           -0.294204
# AvgOrderRate_End                         -0.274445
# AvgOrderRate_Start                       -0.239828
# Name: Churned, dtype: float64

# %%
visualization_df = pd.read_csv("../Data/visualization_data.csv")

# %%
visualization_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8871 entries, 0 to 8870
# Data columns (total 368 columns):
#  #    Column                                Dtype
# ---   ------                                -----
#  0    ClientID                              int64
#  1    Gender                                object
#  2    Age                                   int64
#  3    IsClientSuspended                     int64
#  4    RiskRate                              object
#  5    NumOfAccounts                         int64
#  6    NumOfClosedAccounts                   int64
#  7    NumOfSuspendedAccounts                int64
#  8    NumOfOrders                           int64
#  9    NumOfCompletedOrders                  int64
#  10   NumOfCanceledOrders                   int64
#  11   TotalExecutedQuantity                 int64
#  12   TotalQuantity                         int64
#  13   AvgPrice                              float64
#  14   SecurityID_0                          float64
#  15   SecurityID_1                          float64
#  306  SecurityID_325                        float64
#  307  SecurityID_326                        float64
#  308  SecurityID_307                        float64
#  309  SecurityID_327                        float64
#  310  SecurityID_328                        float64
#  311  SecurityID_329                        float64
#  312  SecurityID_330                        float64
#  313  SecurityID_332                        float64
#  314  SecurityID_333                        float64
#  315  SecurityID_334                        float64
#  316  SecurityID_335                        float64
#  317  SecurityID_336                        float64
#  318  SecurityID_337                        float64
#  319  OrderType_Buy                         float64
#  320  OrderType_Sell                        float64
#  321  ExecutionStatus_Executed              float64
#  322  ExecutionStatus_NotExecuted           float64
#  323  ExecutionStatus_PartiallyExecuted     float64
#  324  SectorName_RealEstate                 float64
#  325  SectorName_Financials                 float64
#  326  SectorName_Materials                  float64
#  327  SectorName_ConsumerDiscretionary      float64
#  328  SectorName_Industries                 float64
#  329  SectorName_HealthCare                 float64
#  330  SectorName_InformationTechnology      float64
#  331  SectorName_ConsumerStaples            float64
#  332  SectorName_INDUSTRIAL                 float64
#  333  SectorName_SERVICES                   float64
#  334  SectorName_Energy                     float64
#  335  SectorName_BasicMaterials             float64
#  336  SectorName_INVESTMENT                 float64
#  337  SectorName_TelecommunicationServices  float64
#  338  SectorName_REALESTATE                 float64
#  339  SectorName_Telecommunications         float64
#  340  SectorName_FOOD                       float64
#  341  SectorName_Others                     float64
#  342  SectorName_Tourism                    float64
#  343  SectorName_ConsumerServices           float64
#  344  SectorName_Utilities                  float64
#  345  SectorName_PharmaceuticalIndustries   float64
#  346  FirstOpenAccountDate                  object
#  347  LastOpenAccountDate                   object
#  348  FirstOrderDateAcrossAccounts          object
#  349  LastOrderDateAcrossAccounts           object
#  350  IsDormant                             int64
#  351  AvgOrderRate_Start                    float64
#  352  AvgOrderRate_End                      float64
#  353  AvgOrderRate_Difference               float64
#  354  AvgQuantityOrderedRate_Start          float64
#  355  AvgQuantityOrderedRate_End            float64
#  356  AvgQuantityOrderedRate_Difference     float64
#  357  AvgQuantityPerAccount_Start           float64
#  358  AvgQuantityPerAccount_End             float64
#  359  AvgQuantityPerAccount_Difference      float64
#  360  AvgExecutedQuantityRatio              float64
#  361  ClosedAccountsRatio                   float64
#  362  SuspendedAccountsRatio                float64
#  363  FirstOpenAccountDate_Year             int64
#  364  LastOpenAccountDate_Year              int64
#  365  FirstOrderDateAcrossAccounts_Year     int64
#  366  LastOrderDateAcrossAccounts_Year      int64
#  367  Churned                               int64
# dtypes: float64(345), int64(17), object(6)
# memory usage: 24.9+ MB

# %%
churned_men = len(
    visualization_df[
        (visualization_df["Gender"] == "Male") & visualization_df["Churned"] == 1
    ]
)
all_men = len(visualization_df[visualization_df["Gender"] == "Male"])

print("Percentage of women that churned: ", churned_men / all_men * 100)
# Out:
# Percentage of women that churned:  21.08369910700772

# %%
churned_women = len(
    visualization_df[
        (visualization_df["Gender"] == "Female") & visualization_df["Churned"] == 1
    ]
)
all_women = len(visualization_df[visualization_df["Gender"] == "Female"])

print("Percentage of women that churned: ", churned_women / all_women * 100)
# Out:
# Percentage of women that churned:  22.791519434628977

# %%
sns.barplot(visualization_df, x="Churned", y="AvgOrderRate_Difference")
# Out:
# <Axes: xlabel='Churned', ylabel='AvgOrderRate_Difference'>

# %%
sns.barplot(visualization_df, x="Churned", y="AvgQuantityOrderedRate_Difference")
# Out:
# <Axes: xlabel='Churned', ylabel='AvgQuantityOrderedRate_Difference'>

# %%
sns.barplot(visualization_df, x="Churned", y="AvgQuantityPerAccount_Difference")
# Out:
# <Axes: xlabel='Churned', ylabel='AvgQuantityPerAccount_Difference'>

# %%
mean_values = (
    visualization_df[visualization_df["Churned"] == 1]
    .iloc[:, 14:319]
    .groupby(visualization_df["Churned"])
    .mean()
)


# Plotting
fig, ax = plt.subplots(figsize=(15, 5))


# Plot the mean values for the churned clients (binary_label == 1)
ax.bar(range(14, 319), mean_values.loc[1], label="Churned")


# Customize the plot
ax.set_xlabel("OHE Feature Index")
ax.set_ylabel("Mean Value")
ax.set_title("Mean Value of OHE Features for Churned Clients")
ax.legend()

# %%
def create_bins(df):
    quantiles = df.quantile([0, 0.1, 0.25, 0.5, 0.8, 1])
    bins_df = pd.cut(
        df, bins=quantiles, labels=["17-29", "28-37", "38-50", "51-65", "69-79"]
    )
    return bins_df

# %%
bins = create_bins(visualization_df["Age"])
visualization_df["Age"] = pd.Series(bins)

# %%
sns.countplot(x="RiskRate", data=visualization_df, hue="Age")
# Out:
# <Axes: xlabel='RiskRate', ylabel='count'>

# %%
sns.countplot(x="IsDormant", data=visualization_df, hue="Age")
# Out:
# <Axes: xlabel='IsDormant', ylabel='count'>

# %%
dormant_clients = visualization_df[visualization_df["IsDormant"] == 1]


# Plot the distribution of the number of accounts
plt.hist(
    dormant_clients["NumOfAccounts"],
    bins=range(1, dormant_clients["NumOfAccounts"].max() + 1),
    edgecolor="black",
)


# Customize the plot
plt.xlabel("Number of Accounts")
plt.ylabel("Frequency")
plt.title("Distribution of Number of Accounts for Dormant Clients")


# Show the plot
plt.show()

# %%
sns.barplot(x="Age", y="NumOfOrders", data=visualization_df, hue="Churned")
# Out:
# <Axes: xlabel='Age', ylabel='NumOfOrders'>

# %%
sns.barplot(x="Age", y="NumOfAccounts", data=visualization_df, hue="Churned")
# Out:
# <Axes: xlabel='Age', ylabel='NumOfAccounts'>

# %%
sns.barplot(x="Age", y="AvgOrderRate_Difference", data=visualization_df, hue="Churned")
# Out:
# <Axes: xlabel='Age', ylabel='AvgOrderRate_Difference'>

# %%
sns.barplot(
    x="Age",
    y="AvgQuantityOrderedRate_Difference",
    data=visualization_df,
    hue="Churned",
)
# Out:
# <Axes: xlabel='Age', ylabel='AvgQuantityOrderedRate_Difference'>

# %%
sns.barplot(
    x="Age", y="AvgQuantityPerAccount_Difference", data=visualization_df, hue="Churned"
)
# Out:
# <Axes: xlabel='Age', ylabel='AvgQuantityPerAccount_Difference'>

# %%
sns.barplot(
    x="Gender", y="AvgOrderRate_Difference", data=visualization_df, hue="Churned"
)
# Out:
# <Axes: xlabel='Gender', ylabel='AvgOrderRate_Difference'>

# %%
sns.barplot(
    x="Gender",
    y="AvgQuantityOrderedRate_Difference",
    data=visualization_df,
    hue="Churned",
)
# Out:
# <Axes: xlabel='Gender', ylabel='AvgQuantityOrderedRate_Difference'>

# %%
sns.barplot(
    x="Gender",
    y="AvgQuantityPerAccount_Difference",
    data=visualization_df,
    hue="Churned",
)
# Out:
# <Axes: xlabel='Gender', ylabel='AvgQuantityPerAccount_Difference'>

# %%
sns.scatterplot(x="Age", y="NumOfOrders", data=visualization_df)
# Out:
# <Axes: xlabel='Age', ylabel='NumOfOrders'>

# %%
sns.countplot(x="NumOfSuspendedAccounts", data=visualization_df, hue="Age")
# Out:
# <Axes: xlabel='NumOfSuspendedAccounts', ylabel='count'>

# %%
sns.countplot(x="NumOfSuspendedAccounts", data=visualization_df, hue="RiskRate")
# Out:
# <Axes: xlabel='NumOfSuspendedAccounts', ylabel='count'>

# %%
sns.countplot(x="Age", data=visualization_df, hue="Churned")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Gender", data=visualization_df, hue="Churned")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="NumOfAccounts", data=visualization_df, hue="Churned")
# Out:
# <Axes: xlabel='NumOfAccounts', ylabel='count'>

# %%
num_of_accounts = visualization_df["NumOfAccounts"].unique()
percentage_churned_per_num_of_accounts = pd.DataFrame()
percentage_churned = []
counts = []
for num in num_of_accounts:
    percentage_churned.append(
        (
            len(
                visualization_df[
                    (visualization_df["NumOfAccounts"] == num)
                    & visualization_df["Churned"]
                    == 1
                ]
            )
            * 100
            / len(visualization_df[(visualization_df["NumOfAccounts"] == num)])
        )
    )
    counts.append(len(visualization_df[(visualization_df["NumOfAccounts"] == num)]))

percentage_churned_per_num_of_accounts["NumOfAccounts"] = pd.Series(num_of_accounts)
percentage_churned_per_num_of_accounts["PercentageOfChurn"] = pd.Series(
    percentage_churned
)
percentage_churned_per_num_of_accounts["Count"] = pd.Series(counts)

percentage_churned_per_num_of_accounts
# Out:
#    NumOfAccounts  PercentageOfChurn  Count
# 0              1          19.273461   6937
# 1              2          34.053700   1527
# 2              3          13.953488    301
# 3              4           8.910891    101
# 4              5          20.000000      5

# %%
sector_columns = [col for col in visualization_df.columns if "SectorName_" in col]

# Create an empty DataFrame to store the results
result = pd.DataFrame(columns=["Sector", "Churned_Percentage"])

for sector in sector_columns:
    # Filter rows where the sector frequency is greater than 1 and churned
    churned = visualization_df[
        (visualization_df[sector] > 0.5) & (visualization_df["Churned"] == 1)
    ]
    # Calculate the percentage
    percentage = (
        1
        if len(visualization_df[visualization_df[sector] > 0.5]) == 0
        else (
            len(churned) / len(visualization_df[visualization_df[sector] > 0.5]) * 100
        )
    )

    # Append the result
    result = pd.concat(
        [
            result,
            pd.DataFrame(
                {
                    "Sector": [sector.replace("SectorName_", "")],
                    "Churned_Percentage": [percentage],
                }
            ),
        ],
        ignore_index=True,
    )

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(result["Sector"], result["Churned_Percentage"])
plt.xlabel("Sector")
plt.ylabel("Percentage of Churned with Frequency > 0.5")
plt.title("Churned Percentage by Sector")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/yf/v551qfjj6kv_0hzcql5wjr7w0000gn/T/ipykernel_35485/499332513.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(
